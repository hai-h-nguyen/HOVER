# %%
import numpy as np

# %%
play = np.load("/home/rtx4/HOVER/play.npy")[0]
play
# Out:
# array([-0.49334496,  0.22011603,  0.46544716, ...,  0.        ,
#         0.        ,  0.        ], dtype=float32)

# %%
sim2sim = np.load("/home/rtx4/HOVER/sim2sim.npy")[0]
sim2sim
# Out:
# array([-0.49334496,  0.22011603,  0.46544716, ...,  0.        ,
#         0.        ,  0.        ], dtype=float32)

# %%
diff = play - sim2sim
diff
# Out:
# array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)

# %%
import matplotlib.pyplot as plt

plt.plot(diff[:200], label='Difference (A - B)', color='r')
plt.title('Difference between corresponding elements of A and B')
plt.xlabel('Index')
plt.ylabel('Difference')
plt.legend()
plt.show()

# %%
pos = np.where(diff != 0)[0]
pos
# Out:
# array([ 46,  47,  48,  49,  50,  51, 125, 126, 128, 129, 131, 132])

# %%
print(pos.shape)
# Out:
# (12,)

# %%
print(play[pos])
# Out:
# [ 0.05168042 -0.19753471  0.02599341  0.21288452 -0.02813332 -0.97667193
#   0.11236523  0.10756464  0.0537791  -0.00710076 -0.0520445   0.42857373]

# %%
print(sim2sim[pos])
# Out:
# [-0.01967177 -0.201328    0.01281059 -0.1157672  -0.10056383 -0.9881725
#   0.1123652   0.14756466  0.05377907  0.03289926 -0.05204449  0.4685738 ]

# %%
play1 = np.load("/home/rtx4/HOVER/play_1.npy")[0]
sim2sim1 = np.load("/home/rtx4/HOVER/sim2sim_1.npy")[0]
diff1 = play1 - sim2sim1
pos = np.where(diff1 != 0)[0]
pos
# Out:
# array([ 46,  47,  48,  49,  50,  51, 125, 126, 128, 129, 131, 132])

# %%
import matplotlib.pyplot as plt

plt.plot(diff1[:200], label='Difference (A - B)', color='r')
plt.title('Difference between corresponding elements of A and B')
plt.xlabel('Index')
plt.ylabel('Difference')
plt.legend()
plt.show()

# %%
play1[pos]
# Out:
# array([ 0.05168042, -0.19753471,  0.02599341,  0.21288452, -0.02813332,
#        -0.97667193,  0.11236523,  0.10756464,  0.0537791 , -0.00710076,
#        -0.0520445 ,  0.4285738 ], dtype=float32)

# %%
sim2sim1[pos]
# Out:
# array([-0.04825172, -0.0367569 ,  0.00890654,  0.21288456, -0.02813333,
#        -0.97667223,  0.1123652 ,  0.14756466,  0.05377907,  0.03289926,
#        -0.05204449,  0.4685738 ], dtype=float32)

# %%
play2 = np.load("/home/rtx4/HOVER/play_2.npy")[0]
sim2sim2 = np.load("/home/rtx4/HOVER/sim2sim_2.npy")[0]
diff2 = play2 - sim2sim2
pos = np.where(diff2 != 0)[0]
pos
# Out:
# array([ 46,  47,  48,  49,  50,  51, 125, 126, 128, 129, 131, 132])

# %%
import matplotlib.pyplot as plt

plt.plot(diff2[:200], label='Difference (A - B)', color='r')
plt.title('Difference between corresponding elements of A and B')
plt.xlabel('Index')
plt.ylabel('Difference')
plt.legend()
plt.show()

# %%
play2[pos]
# Out:
# array([ 0.01368348, -0.0226622 ,  0.04418666,  0.21288452, -0.02813332,
#        -0.97667193,  0.11236523,  0.10756464,  0.0537791 , -0.00710076,
#        -0.0520445 ,  0.4285738 ], dtype=float32)

# %%
sim2sim2[pos]
# Out:
# array([-0.04825172, -0.0367569 ,  0.00890654,  0.21288456, -0.02813333,
#        -0.97667223,  0.1123652 ,  0.14756466,  0.05377907,  0.03289926,
#        -0.05204449,  0.4685738 ], dtype=float32)

# %%
import numpy as np
import pickle

# %%
# load file npz
with open('/home/rtx4/HOVER/test.pkl', 'rb') as f:
    data = pickle.load(f)
data
# Out:
# [{'robot_state': {'root_pos': array([[-0.0645389 , -0.3331109 ,  0.8038822 ],
#           [-0.06040954, -0.32649553,  0.80220944],
#           [-0.05605993, -0.32285684,  0.79563534],
#           [-0.05494779, -0.32420674,  0.78759676],
#           [-0.05868167, -0.32923433,  0.78381836],
#           [-0.06069326, -0.3360546 ,  0.78251034],
#           [-0.06256422, -0.34001604,  0.78330904],
#           [-0.063778  , -0.34319204,  0.7844439 ],
#           [-0.06465697, -0.34547955,  0.7852487 ],
#           [-0.06527591, -0.3478502 ,  0.78537416],
#           [-0.06613522, -0.35028678,  0.78524566],
#           [-0.06718495, -0.3518592 ,  0.7853616 ],
#           [-0.06865347, -0.3519649 ,  0.7861616 ],
#           [-0.07017542, -0.3513494 ,  0.7873476 ],
#           [-0.07129126, -0.3509368 ,  0.78867954],
#           [-0.07223326, -0.35052443,  0.7898943 ],
#           [-0.07331996, -0.34942603,  0.79036176],
#           [-0.07475991, -0.34699756,  0.7891998 ],
# ...

# %%
for i in data:
    print(i)
# Out:
# {'robot_state': {'root_pos': array([[-0.0645389 , -0.3331109 ,  0.8038822 ],
#        [-0.06040954, -0.32649553,  0.80220944],
#        [-0.05605993, -0.32285684,  0.79563534],
#        [-0.05494779, -0.32420674,  0.78759676],
#        [-0.05868167, -0.32923433,  0.78381836],
#        [-0.06069326, -0.3360546 ,  0.78251034],
#        [-0.06256422, -0.34001604,  0.78330904],
#        [-0.063778  , -0.34319204,  0.7844439 ],
#        [-0.06465697, -0.34547955,  0.7852487 ],
#        [-0.06527591, -0.3478502 ,  0.78537416],
#        [-0.06613522, -0.35028678,  0.78524566],
#        [-0.06718495, -0.3518592 ,  0.7853616 ],
#        [-0.06865347, -0.3519649 ,  0.7861616 ],
#        [-0.07017542, -0.3513494 ,  0.7873476 ],
#        [-0.07129126, -0.3509368 ,  0.78867954],
#        [-0.07223326, -0.35052443,  0.7898943 ],
#        [-0.07331996, -0.34942603,  0.79036176],
#        [-0.07475991, -0.34699756,  0.7891998 ],
#        [-0.07522257, -0.34317344,  0.7884744 ],
# ...
